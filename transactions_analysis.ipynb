# %%
import pandas as pd

file = "top_10000_btc_wallets.csv"
df = pd.read_csv(file)
df = df.set_index('ranking')

df.head()
# Out:
#                                               address_full  \
# ranking
# 1        34xp4vRoCGJym3xR7yCVPFHoCNxv4Twseowallet: Bina...
# 2        35hK24tcLEWcgNA4JxpvbkNkoAcDGqQPsP 3-of-7walle...
# 3        385cR5DM96n1HvBDMzLHPYcw89fZAXULJPwallet: Bitt...
# 4                3CgKHXR17eh2xCj2RGnHJHTDjPpqaNDgyT 2-of-3
# 5                       37XuVSEpWW4trkfmvWzegTHQt7BdktSKUs
#
#                                                    balance percentage_coins  \
# ranking
# 1        171,790 BTC ($1,618,882,625 USD) +8125 BTC / +...          0.9537%
# 2        151,001 BTC ($1,422,979,592 USD) +0.9994 BTC /...          0.8383%
# 3             117,305 BTC ($1,105,438,685 USD) / -1500 BTC          0.6512%
# 4                         111,858 BTC ($1,054,111,319 USD)          0.6210%
# 5                            94,506 BTC ($890,587,902 USD)          0.5246%
#
#                         first_in                  last_in  number_ins  \
# ranking
# ...

# %%
df.columns
# Out:
# Index(['address_full', 'balance', 'percentage_coins', 'first_in', 'last_in',
#        'number_ins', 'first_out', 'last_out', 'number_outs'],
#       dtype='object')
