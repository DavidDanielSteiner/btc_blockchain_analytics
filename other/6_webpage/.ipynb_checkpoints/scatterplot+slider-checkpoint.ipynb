# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import numpy as np
import plotly.graph_objs as go
import datetime

app = dash.Dash()

# %%
np.random.seed(50)
x_rand = np.random.randint(1,61,60)
y_rand = np.random.randint(1,61,60)

# %%
app.layout = html.Div([
    
    dcc.Graph(
        id='scatter_chart',
        figure = {
            'data' : [
                go.Scatter(
                    x = x_rand,
                    y = y_rand,
                    mode = 'markers'
                )
            ],
            'layout' : go.Layout(
                title = "title",
                xaxis = {'title' : 'Random X values'},
                yaxis = {'title' : 'Random Y values'},
            )
            
        }
    ),
    html.Label('Date'),
    dcc.RangeSlider(
        id = 'slider1',
        min = min(x_rand),
        max = max(x_rand),
        value = [10,20],
        #print(min),
        step = 1,
        marks = {i: i for i in range(8)}
    ),
    html.Label('Balance'),
    dcc.RangeSlider(
        min = 1,
        max = 8,
        value = [3,5],
        step = .5,
        marks = {i: i for i in range(8)}
    ),
    html.Div(id='output-container-range-slider'),
],
    # not spanning the entire screen
    style={'width': '50%',
               'display': 'inline-block'},
)

# %%
@app.callback(
    dash.dependencies.Output('output-container-range-slider', 'children'),
    [dash.dependencies.Input('my-range-slider', 'value')])
def update_output(value):
    return 'You have selected "{}"'.format(value)
# Out:
# ---------------------------------------------------------------------------
# NonExistentIdException                    Traceback (most recent call last)
# <ipython-input-31-e2c8a7022393> in <module>
#       1 @app.callback(
#       2     dash.dependencies.Output('output-container-range-slider', 'children'),
# ----> 3     [dash.dependencies.Input('my-range-slider', 'value')])
#       4 def update_output(value):
#       5     return 'You have selected "{}"'.format(value)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dash\dash.py in callback(self, output, inputs, state)
#    1262     # pylint: disable=dangerous-default-value
#    1263     def callback(self, output, inputs=[], state=[]):
# -> 1264         self._validate_callback(output, inputs, state)
#    1265
#    1266         callback_id = _create_callback_id(output)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dash\dash.py in _validate_callback(self, output, inputs, state)
#     937                             `suppress_callback_exceptions=True`.
#     938                         """
# --> 939                             ).format(arg_id, all_ids)
#     940                         )
#     941
#
# NonExistentIdException:
#                             Attempting to assign a callback to the
#                             component with the id "my-range-slider" but no
#                             components with id "my-range-slider" exist in the
#                             app's layout.
#
#
#                             Here is a list of IDs in layout:
# ['scatter_chart', 'slider1', 'output-container-range-slider']
#
#
#                             If you are assigning callbacks to components
#                             that are generated by other callbacks
#                             (and therefore not in the initial layout), then
#                             you can suppress this exception by setting
#                             `suppress_callback_exceptions=True`.

# %%
if __name__ == "__main__":
    app.run_server(port=4050)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Nov/2019 12:11:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:24] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:24] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:24] "GET /_favicon.ico?v=1.5.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2019 12:11:43] "POST /_dash-update-component HTTP/1.1" 200 -
